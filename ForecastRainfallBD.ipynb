# %%
import numpy as np 
import pandas as pd 
import os
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
import warnings

warnings.filterwarnings("ignore")

# %%
rainBd = pd.read_csv('BD.csv')

# %%
rainBd.head()
# Out:
#    StationIndex Station  Year  Month  Day  Rainfall      Date  Rain Status
# 0             1   Dhaka  1970      1    1         0  1/1/1970            0
# 1             1   Dhaka  1970      1    2         0  1/2/1970            0
# 2             1   Dhaka  1970      1    3         0  1/3/1970            0
# 3             1   Dhaka  1970      1    4         0  1/4/1970            0
# 4             1   Dhaka  1970      1    5         0  1/5/1970            0

# %%
rainBd.shape
# Out:
# (542376, 8)

# %%
rainBd.nunique()
# Out:
# StationIndex       35
# Station            35
# Year               47
# Month              12
# Day                31
# Rainfall          345
# Date            17167
# Rain Status         2
# dtype: int64

# %%
rainBd=rainBd.drop(['StationIndex','Year','Month','Day'],axis=1)
rainBd.columns
# Out:
# Index(['Station', 'Rainfall', 'Date', 'Rain Status'], dtype='object')

# %%
# rainBd=rainBd.drop(['Station'],axis=1)
le = preprocessing.LabelEncoder()
rainBd['Station'] = le.fit_transform(rainBd['Station'])
rainBd['Date'] = le.fit_transform(rainBd['Date'])

# %%
# rainBd=rainBd.drop(['Date'],axis=1)
# rainBd.columns

# %%
x_train, x_test, y_train, y_test = train_test_split(rainBd.iloc[:,:-1], rainBd.iloc[:,-1], test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor(n_estimators = 100, random_state = 0)  
model.fit(x_train, y_train)  
predicted = model.predict(x_test)
print("The accuracy of Random Forest is : ", accuracy_score(y_test, predicted.round())*100, "%")
# Out:
# The accuracy of Random Forest is :  100.0 %
